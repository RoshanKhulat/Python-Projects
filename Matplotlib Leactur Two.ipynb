# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image as img

# %% [markdown]
# ### Pie Chart

# %%
x = [10,20,30,40]
y = ['English','Hindi','Marathi','Mix']

plt.pie(x , labels = y)
plt.show()
